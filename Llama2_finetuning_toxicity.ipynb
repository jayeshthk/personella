# %% [markdown]
# <a href="https://colab.research.google.com/github/jayeshthk/personella/blob/main/Llama2_finetuning_toxicity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Necessary Libraries

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 91.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 46.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 90.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 75.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 28.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %% [markdown]
# # Dataset details
# Instacart Data can be downloaded from [here](https://www.kaggle.com/competitions/instacart-market-basket-analysis/data). We just need product & department csv files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/'Colab Notebooks'
# Out:
# departments.csv  products.csv

# %%
import pandas as pd
df_product = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/products.csv")
df_dept = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/departments.csv')

# %%
df_joined = pd.merge(df_product, df_dept, on = ['department_id'])
df_joined['text'] = df_joined.apply(lambda row: row['product_name'] + " ->: " + row['department'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df_joined, test_size=0.2, random_state=42)

# %%
train_df.head(10)
# Out:
#        product_id                                       product_name  \
# 7361        10376                              Organic Caraway Seeds
# 32534       40131                         Original Laundry Detergent
# 1457        11913                                 Shelled Pistachios
# 5201        41392                   Harvest Berry Chewy Granola Bars
# 38539       28627              Veganic Sprouted Red Fife Raisin Bran
# 18377       29407                               Root Vegetable Cakes
# 28627       29571                                  Alta Dena 1% Milk
# 30283        3589                             Laundry Detergent Pods
# 32030       31685  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655       30119            Organic French Style Meyer Lemon Yogurt
#
#        aisle_id  department_id  department  \
# 7361        104             13      pantry
# 32534        75             17   household
# 1457        117             19      snacks
# 5201          3             19      snacks
# 38539       121             14   breakfast
# 18377        42              1      frozen
# 28627        84             16  dairy eggs
# 30283        75             17   household
# 32030       114             17   household
# 28655       120             16  dairy eggs
#
#                                                     text
# 7361                    Organic Caraway Seeds ->: pantry
# 32534           Original Laundry Detergent ->: household
# 1457                       Shelled Pistachios ->: snacks
# 5201         Harvest Berry Chewy Granola Bars ->: snacks
# 38539  Veganic Sprouted Red Fife Raisin Bran ->: brea...
# 18377                    Root Vegetable Cakes ->: frozen
# 28627                   Alta Dena 1% Milk ->: dairy eggs
# 30283               Laundry Detergent Pods ->: household
# 32030  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655  Organic French Style Meyer Lemon Yogurt ->: da...

# %%
test_df.head(10)
# Out:
#        product_id                                       product_name  \
# 33626       24154             Free & Clear Stage 4 Overnight Diapers
# 18192       27348  Beef pot roast with roasted potatoes, carrots,...
# 47099       27181                                      Coffee Liquer
# 48183       20577                                        Bread Rolls
# 22197       16472           French Milled Oval Almond Gourmande Soap
# 31573       24121                                           Dust Pan
# 45362        5477                            Roasted Pine Nut Hommus
# 14131       27921                 Cranberry Raspberry Juice Cocktail
# 26903        4786                          Sweet Cream Butter Salted
# 39417        8796                    Traditional Chicken Barley Soup
#
#        aisle_id  department_id     department  \
# 33626        56             18         babies
# 18192        38              1         frozen
# 47099       124              5        alcohol
# 48183        43              3         bakery
# 22197        25             11  personal care
# 31573       114             17      household
# 45362        67             20           deli
# 14131        98              7      beverages
# 26903        36             16     dairy eggs
# 39417        69             15   canned goods
#
#                                                     text
# 33626  Free & Clear Stage 4 Overnight Diapers ->: babies
# 18192  Beef pot roast with roasted potatoes, carrots,...
# 47099                          Coffee Liquer ->: alcohol
# 48183                             Bread Rolls ->: bakery
# 22197  French Milled Oval Almond Gourmande Soap ->: p...
# 31573                             Dust Pan ->: household
# 45362                   Roasted Pine Nut Hommus ->: deli
# 14131   Cranberry Raspberry Juice Cocktail ->: beverages
# 26903           Sweet Cream Butter Salted ->: dairy eggs
# 39417   Traditional Chicken Barley Soup ->: canned goods

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(train_df),
})

# %% [markdown]
# ## Loading the model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "TinyPixel/Llama-2-7B-bf16-sharded"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00014.bin:   0%|          | 0.00/981M [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00008-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00009-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00010-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00011-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00012-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00013-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00014-of-00014.bin:   0%|          | 0.00/847M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %%
import pandas as pd
df=pd.read_csv("df_joined_toxicity_training.csv")

# %%
df['text']=df.apply(lambda row: f''' Extract toxic phrase and type of toxicities if available from content in JSON format {row['content']} '''  + " ->: " + row['toxicity'], axis = 1)

# %%
df
# Out:
#                                                content  \
# 0    ... A rose by any other name would smell just ...
# 1    > THE PURPLE HAT\n>\n> Beautiful Women\n>\n> A...
# 2    > You know you are from California when..........
# 3    A police officer pulls a guy over for speeding...
# 4    A police officer pulls a guy over for speeding...
# ..                                                 ...
# 915  respond/aflow/src/com/sitraka/wfms/common/Util...
# 916  shashi and i checked in the following files on...
# 917  thanks Peter, for the fucking update.  Tonight...
# 918  this is for White-White LLC  Original Message ...
# 919                                   x-up-subno:null
#
#                                               toxicity  \
# 0    [{'toxicity': True, 'toxic_phrase': 'NOT!', 'c...
# 1    [{'toxicity': True, 'toxic_phrase': 'your left...
# 2    [{'toxicity': True, 'toxic_phrase': 'Is Pot Il...
# 3    [{'toxicity': True, 'toxic_phrase': 'I stole i...
# 4    [{'toxicity': True, 'toxic_phrase': 'Liar', 'c...
# ..                                                 ...
# 915  [[    {        "toxicity": True,        "toxic...
# 916  [{"toxicity": False,"toxic_phrase": "","catego...
# 917  {"toxicity": True,"toxic_phrase": "fucking","c...
# 918  [ {"toxicity": False,"toxic_phrase": "","categ...
# 919  [ {"toxicity": False,"toxic_phrase": "","categ...
#
#                                                   text
# 0     Extract toxic phrase and type of toxicities i...
# 1     Extract toxic phrase and type of toxicities i...
# 2     Extract toxic phrase and type of toxicities i...
# 3     Extract toxic phrase and type of toxicities i...
# 4     Extract toxic phrase and type of toxicities i...
# ..                                                 ...
# 915   Extract toxic phrase and type of toxicities i...
# 916   Extract toxic phrase and type of toxicities i...
# 917   Extract toxic phrase and type of toxicities i...
# 918   Extract toxic phrase and type of toxicities i...
# 919   Extract toxic phrase and type of toxicities i...
#
# [920 rows x 3 columns]

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(df),
})

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    # target_modules=["q_proj","v_proj"]
    target_modules=['q_proj', 'o_proj', 'gate_proj', 'up_proj', 'down_proj', 'k_proj', 'v_proj'] # Choose all linear layers from the model
)

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 1
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 35
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
    ddp_find_unused_parameters=False,
)

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:107: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/920 [00:00<?, ? examples/s]

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %%
import wandb
wandb.init(mode="disabled")

# %%
import torch
torch.cuda.empty_cache()

import gc
gc.collect()
# Out:
# 48

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='17' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [17/35 14:37 < 17:32, 0.02 it/s, Epoch 0.28/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.046700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.088400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.666400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.077400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.961000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.035200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.050400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.023300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.949100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.241900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.112400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.873200</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.139500</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.627500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.574600</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3435b262f1ae> in <cell line: 1>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1589                 hf_hub_utils.enable_progress_bars()
#    1590         else:
# -> 1591             return inner_training_loop(
#    1592                 args=args,
#    1593                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1982                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    1983
# -> 1984                     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1985                 else:
#    1986                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    2337
#    2338         if self.control.should_save:
# -> 2339             self._save_checkpoint(model, trial, metrics=metrics)
#    2340             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    2341
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial, metrics)
#    2394         run_dir = self._get_output_dir(trial=trial)
#    2395         output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 2396         self.save_model(output_dir, _internal_call=True)
#    2397         if self.is_deepspeed_enabled:
#    2398             # under zero3 model file itself doesn't get saved since it's bogus! Unless deepspeed
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in save_model(self, output_dir, _internal_call)
#    2899
#    2900         elif self.args.should_save:
# -> 2901             self._save(output_dir)
#    2902
#    2903         # Push to the Hub when `save_model` is called by the user.
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _save(self, output_dir, state_dict)
#    2957                     torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    2958         else:
# -> 2959             self.model.save_pretrained(
#    2960                 output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    2961             )
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in save_pretrained(self, save_directory, safe_serialization, selected_adapters, **kwargs)
#     194                 )
#     195             else:
# --> 196                 torch.save(output_state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#     197
#     198             # save the config and change the inference mode to `True`
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439     if _use_new_zipfile_serialization:
#     440         with _open_zipfile_writer(f) as opened_zipfile:
# --> 441             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442             return
#     443     else:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     666         # Now that it is on the CPU we can directly copy it into the zip file
#     667         num_bytes = storage.nbytes()
# --> 668         zip_file.write_record(name, storage.data_ptr(), num_bytes)
#     669
#     670
#
# KeyboardInterrupt:

# %% [markdown]
# **Let's check what the base model predicts before finetuning. :)**

# %%
import transformers
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)


sequences = pipeline(
   ["“Free & Clear Stage 4 Overnight Diapers” ->:","Bread Rolls ->:","French Milled Oval Almond Gourmande Soap ->:"],
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq[0]['generated_text']}")
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Result: “Free & Clear Stage 4 Overnight Diapers” ->: http://www. Einzeln: 32,56 â‚¬.
# The price of the “Free & Clear Overnight Pull-Ups” is 34.48 â‚¬, the price of the “Free & Clear Stage 2 Overnight Pull-Ups” is 30.26 â‚¬.
# The offer is only valid until 23.07.2005 and is available at the following online shops:
# http://www.aldi-sued.de
# http://www.aldi-nord.de
# http://www.aldi-sued.at
# The offer is available at the following webshop
# http://www.aldi-sued.at
# The following webshops are offering the product “Free & Clear Overnight Pull-Ups”
# Result: Bread Rolls ->:
#  kwietnia 09, 2015 at 7:21 am
# You’re so interesting! I do not suppose I have read through a
# single thing like that before. So good to find another person with a few unique thoughts on this issue.
# Serwis Komputerowy Lublin
# april 18, 2015 at 3:06 am
# It’s remarkable to go to seveг a great site
# that offers helpful information about ѕex.
# Sweetie 3D
# aprill 18, 2015 at 4:02 pm
# What i do not understand is in truth how you’re no longer
# actually much more well-appreciated than you might be
# Now you’re not only a stunning and intelligent woman, but an incredibly funny, and funny, too
# Result: French Milled Oval Almond Gourmande Soap ->: http://amzn. sierp 12, 2012... Aromatherapy uses essential oils to enhance physical, mental, and emotional wellness. These oils are usually extracted from plants.Essential Oils, Natural Aromatherapy and Fruit Extracts for Natural Skin Care. 6,619 likes · 90 talking about this. We are committed to offering you the best products that nature can provide in...Feb 24, 2021 · The 20 best essential oils to try this summer. The essential oils market is booming.... The oil is used to treat anxiety, stress, fatigue, and sleep problems. 22. Frankincense essential... Aromatherapy has been used for centuries to help promote wellness. Essential oils can be used as part

# %% [markdown]
# Below we will load the configuration file in order to create the LoRA model. According to QLoRA paper, it is important to consider all linear layers in the transformer block for maximum performance.

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj","v_proj"]
)

# %% [markdown]
# ## Loading the trainer

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Then finally pass everthing to the trainer

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/39750 [00:00<?, ? examples/s]

# %% [markdown]
# We will also pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Now let's train the model! Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/content/wandb/run-20230723_133543-t92baap2</code>
# Syncing run <strong><a href='https://wandb.ai/imsamread81/huggingface/runs/t92baap2' target="_blank">genial-wildflower-34</a></strong> to <a href='https://wandb.ai/imsamread81/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/imsamread81/huggingface' target="_blank">https://wandb.ai/imsamread81/huggingface</a>
#  View run at <a href='https://wandb.ai/imsamread81/huggingface/runs/t92baap2' target="_blank">https://wandb.ai/imsamread81/huggingface/runs/t92baap2</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 06:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.029100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.089600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.359200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.271200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.250100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.092700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.517300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.969400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.471400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>5.357300</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>4.242900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.114000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6.103300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>4.110700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4.049400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.912300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>4.855500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.832500</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.769600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.626600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.243700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>4.343500</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>3.275000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.072400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.953700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>4.202900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>3.073900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.548200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.647600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.480100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.821500</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.338400</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.635800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.777900</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.439800</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2.471600</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.252500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.435800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.471000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.127300</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.303000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.183800</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.180300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.015000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.095800</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>3.213900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.318600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.834600</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.410100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.020200</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.725400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.724000</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.445000</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>3.040600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>3.940100</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.523000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.474000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.230000</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.376400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.171800</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.267000</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.513400</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.142000</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.752800</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.013900</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>2.094100</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>2.002200</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.568000</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>2.038200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.310100</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>3.925900</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.956000</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.830700</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>2.109700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.248200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.292800</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.212300</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>2.406900</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>2.302600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.290100</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>2.078400</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>2.010800</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>2.103700</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>2.211600</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>2.893500</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.235800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>2.062900</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.952200</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.960700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.850700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>2.047100</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>2.007600</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>2.029300</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>2.401800</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.075800</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.151300</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>2.436300</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>2.245300</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>3.021100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.618400</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>4.818500</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>2.188500</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.040600</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.335400</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>2.368200</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.422600</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.047000</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>2.237700</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>2.114600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.076000</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.125600</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.927700</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.773400</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.236300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.222000</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>2.790600</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.900300</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.946700</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>2.131300</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.033300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.6939144556721053, metrics={'train_runtime': 410.6557, 'train_samples_per_second': 4.675, 'train_steps_per_second': 0.292, 'total_flos': 627303342243840.0, 'train_loss': 2.6939144556721053, 'epoch': 0.05})

# %%
lst_test_data = list(test_df['text'])

# %%
len(lst_test_data)
# Out:
# 9938

# %%
sample_size = 25
lst_test_data_short = lst_test_data[:sample_size]

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    lst_test_data_short,
    max_length=100,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# 0 Free & Clear Stage 4 Overnight Diapers ->: babies: diapers & accessories diapers ->: baby needs diapers & pads free clear diapers ->: baby needs diapers free & clear stage 4 overnight diapers: diapers ->: baby needs diapers diapers & accessories ->: baby needs diapers free & clear stage 4 overnight diapers: diapers ->: personal care baby care ->: diapers & accessories dia
# 1 Beef pot roast with roasted potatoes, carrots, sweet onions, green beans, and a rich gravy Beef Pot Roast ->: frozen goods ->: frozen meals ->: meat, chicken & seafood ->: beef & beef products ->: entree ->: entree ->: entree ->: entrees: beef ->: beef entree ->: meat ->: beef ->: meat, chicken
# 2 Coffee Liquer ->: alcoholic beverages spirits ->: beverages beer & hard cider ->: beer coffee liqueur ->: beverages liquor ->: beverages beer & hard cider coffee liquor ->: beverages beer coffee liqueur original ->: beverages liquor ->: beverages beer & hard cider coffee liqueur original alcoholic beverages spirits drinks beer
# 3 Bread Rolls ->: bakery ->: frozen ->: breads & pastries ->: frozen ->: bakery ->: frozen breads & pastry ->: frozen bread ->: english muffin ->: english muffin ->: frozen bread ->: breads & pastries ->: frozen breads & pastries ->: bakery ->: frozen ->: breads & pastries ->: frozen breads
# 4 French Milled Oval Almond Gourmande Soap ->: personal care soap & bath ->: toiletries body care: soaps ->: body care: personal care: bathroom: personal care soaps personal care soaps: soap ->: personal care soaps: soap ->: personal care toiletries: toiletries personal care: body care: soaps ->: personal care soaps: soap: almond soap: personal care oval ->: personal
# 5 Dust Pan ->: household: pantry: cleaning: broom & mop: broom & broom brushes: hand broom ->: household: pantry: cleaning: broom & mop: dust pans: dust pan ->: tools & garden: gardening ->: household: pantry: cleaning: broom & mop: hand broom ->: household: pantry: cleaning: broom & mop: mops: clean
# 6 Roasted Pine Nut Hommus ->: deli meats & cheese ->: snacks ->: snack foods ->: snacks ->: dip & spread ->: dips & spreads ->: hommus ->: dip & spread ->: dip & spread ->: dip ->: hummus ->: dip & spread ->: hummus ->: dip ->: dips ->: pine nut roasted hommus dip ->: dip ->: pine nut
# 7 Cranberry Raspberry Juice Cocktail ->: beverages alcohol juice cranberry raspberry juice cocktail ->: drinks juice beverages juice drinks ->: beverages juice drinks beverages juice drinks juice cocktail ->: beverages beverages drinks ->: beverages juice juice drinks ->: beverages juice drinks beverages juice
# 8 Sweet Cream Butter Salted ->: dairy eggs butter & cheese eggs ->: baking & dairy butter sweet cream butter salted ->: dairy dairy eggs cheeses eggs ->: dairy eggs butter & cheese: eggs: butter & cheese sweet cream butter ->: pantry items pantry products eggs butter & cheese: butter & cheese sweet cream butter ->: baking baking ing
# 9 Traditional Chicken Barley Soup ->: canned goods ->: soups, stews & pasta ->: canned soup ->: chicken soups ->: chicken broth ->: traditional chicken broth ->: chicken broth & chicken stock ->: traditional broth & stock ->: soup ->: traditional chicken broth ->: traditional chicken broth ->: soup ->: chicken barley broth ->: traditional chicken barley soup
# 10 Vanilla Unsweetened Cashewmilk ->: dairy eggs & dairy eggs ->: dairy beverages ->: dairy beverages ->: beverages ->: dairy: beverages & smoothies drinks ->: beverages non-alcoholic drinks ->: beverages non-alcoholic beverages ->: beverages non-alcoholic dairy beverages ->: dairy be
# 11 Minis Size Chocolate Candy Bars Variety Mix ->: snacks chocolate & candy ->: snacks ->: candy ->: confections ->: snack ->: snacks chocolate & candy ->: confections ->: snack ->: snacks ->: snacks ->: snacks chocolate & candy ->: snacks ->: candy ->: candy bars ->: chocolate ->: milk choc
# 12 Cheesy Cheddar Rotini Pasta Sides ->: dry goods pasta, rice, beans and grains pasta ->: dry goods pasta ->: pasta ->: pasta sides, meals & mixes pasta sides, meals & mixes cheesy cheese pasta, rotini ->: other household items other household items: pasta ->: pasta sides, meals & mixes pasta sides, meals & mixes che
# 13 Multi Purpose Solution ->: personal care toiletries personal care toiletries liquid hand wash & dish wash ->: laundry detergent & fabric softener laundry detergent liquid & fabric softener dryer sheets ->: cleaning supplies laundry detergent dish soap ->: personal care toiletries personal care toiletries liquid hand wash & dish wash dishwasher soap detergent ->
# 14 Juice, Raw & Cold-Pressed, Purity ->: beverages ->: beverages ->: beverages ->: organic cold pressed juice ->: organic cold pressed juice ->: fruit juice ->: fruit juice ->: fruit ->: organic ->: beverages ->: beverages ->: beverages ->: fruit ->: organic ->: fruit juice ->: fruit juice ->: fruit ->: organic ->:
# 15 Chinese Five Spices Powder ->: international foods dry goods spices & seasonings spices five spices ->: pantry dry goods spices, herbs & seasonings spices mixes five spice ->: pantry pasta, rice, dry goods pancakes & waffles ->: snacks & sweets snack chips snack foods ->: snack foods potato chips chippy fries chips ->: snack foods
# 16 Ancient Grain Original Granola ->: breakfast cereals ->: organic ->: breakfast foods original granola cereal ->: cereal, oats, rice & cereal products ->: cereals, granolas & pancakes, organic ->: cereals, granolas & pancakes, organic, cereal & granola organic, ancient grain original granola granola ->: breakfast cereals breakfast cere
# 17 Crunch Lemon Shortbread Flavor 0% Fat with Toppings Greek Yogurt ->: dairy eggs & cheese frozen dairy ->: ice cream ->: ice cream flavors ->: ice creams, sherbet & toppings ->: ice cream ->: toppings ->: ice cones ->: toppings ->: candy ->: frozen cones ->: toppings ->: candy & toppings ->: fro
# 18 Flounder Fillets ->: meat seafood frozen ->: seafood ->: shrimp & shellfish ->: frozen seafood ->: frozen seafood ->: seafood ->: fish frozen ->: frozen seafood ->: seafood ->: seafoods ->: frozen fish: flounder fillets frozen seafood ->: seafood ->: shellfish frozen seafood ->: sea
# 19 Lilac Votive ->: household essentials candles & accessories scented votive wax tablets ->: candles & lanterns votive candles ->: house cleaning laundry detergent & cleaning products laundry detergent products dryer sheets & softener sheets scented wax tablets ->: household essentials candles & accessories scented votive wax tablets purple ->: household essentials candles & accessories
# 20 Cheese & Broccoli Ravioli For Kids ->: frozen food ->: snacks ->: frozen meals, entree ->: frozen meals ->: poultry ->: frozen entree ->: frozen pasta ->: frozen meals, entree ->: frozen meals ->: pasta ->: frozen pasta ->: frozen pasta ->: pasta ->: poultry ->: pasta ->: che
# 21 Organic Soymilk Original Value Size ->: dairy eggs dairy egg products soy products ->: soy products beverages milk ->: beverages soymilk soy milks ->: organic soymilk original value size original soymilk ->: dairy eggs dairy egg products soy products soymilk organic organic soymilk ->: beverages soymilk ->: soy products beverages
# 22 Fruit Juice Sweetened Millet Rice Cereal ->: breakfast foods ->: pantry items ->: cereal pasta ->: cereals ->: fruit & oatmeal ->: cereal pasta snacks ->: organic snack cereal ->: snacks ->: snack cereal ->: fruit juice sweetened millet rice cereal ->: other ->: pantry items ->: cere
# 23 Morning Burst® Facial Scrub Cleansers ->: personal care ->: face ->: facial scrubs ->: cleansers, masks, exfoliators, & moisturizers ->: personal care ->: face facial scrubs ->: cleaners, masks, exfoliators, & moisturizers morning burst ->: personal care ->: face ->: cleansers, masks, exfoliators, & moist
# 24 Salmon Pinwheels ->: meat seafood fish seafood ->: fish seafood scallops ->: seafood frozen fish ->: fish fillets ->: seafood frozen salmon products ->: frozen seafood snacks seafood snacks ->: snack foods snack snacks ->: snack foods seafood appetizers snacks ->: snacks frozen appetizers ->: frozen sea

# %%
def correct_answer(ans):
  return (ans.split("->:")[1]).strip()

answers = []
for ix,seq in enumerate(sequences):
    # print(ix,seq[0]['generated_text'])
    answers.append(correct_answer(seq[0]['generated_text']))

answers
# Out:
# ['babies: diapers & accessories diapers',
#  'frozen goods',
#  'alcoholic beverages spirits',
#  'bakery',
#  'personal care soap & bath',
#  'household: pantry: cleaning: broom & mop: broom & broom brushes: hand broom',
#  'deli meats & cheese',
#  'beverages alcohol juice cranberry raspberry juice cocktail',
#  'dairy eggs butter & cheese eggs',
#  'canned goods',
#  'dairy eggs & dairy eggs',
#  'snacks chocolate & candy',
#  'dry goods pasta, rice, beans and grains pasta',
#  'personal care toiletries personal care toiletries liquid hand wash & dish wash',
#  'beverages',
#  'international foods dry goods spices & seasonings spices five spices',
#  'breakfast cereals',
#  'dairy eggs & cheese frozen dairy',
#  'meat seafood frozen',
#  'household essentials candles & accessories scented votive wax tablets',
#  'frozen food',
#  'dairy eggs dairy egg products soy products',
#  'breakfast foods',
#  'personal care',
#  'meat seafood fish seafood']

# %%
df_evaluate = test_df.iloc[:sample_size][['product_name','department']]

df_evaluate = df_evaluate.reset_index(drop=True)

df_evaluate['department_predicted'] = answers

df_evaluate
# Out:
#                                          product_name       department  \
# 0              Free & Clear Stage 4 Overnight Diapers           babies
# 1   Beef pot roast with roasted potatoes, carrots,...           frozen
# 2                                       Coffee Liquer          alcohol
# 3                                         Bread Rolls           bakery
# 4            French Milled Oval Almond Gourmande Soap    personal care
# 5                                            Dust Pan        household
# 6                             Roasted Pine Nut Hommus             deli
# 7                  Cranberry Raspberry Juice Cocktail        beverages
# 8                           Sweet Cream Butter Salted       dairy eggs
# 9                     Traditional Chicken Barley Soup     canned goods
# 10                     Vanilla Unsweetened Cashewmilk       dairy eggs
# 11        Minis Size Chocolate Candy Bars Variety Mix           snacks
# 12                  Cheesy Cheddar Rotini Pasta Sides  dry goods pasta
# 13                             Multi Purpose Solution    personal care
# 14                  Juice, Raw & Cold-Pressed, Purity        beverages
# 15                         Chinese Five Spices Powder    international
# 16                     Ancient Grain Original Granola        breakfast
# 17  Crunch Lemon Shortbread Flavor 0% Fat with Top...       dairy eggs
# 18                                   Flounder Fillets     meat seafood
# 19                                       Lilac Votive        household
# 20                 Cheese & Broccoli Ravioli For Kids           frozen
# 21                Organic Soymilk Original Value Size       dairy eggs
# 22           Fruit Juice Sweetened Millet Rice Cereal        breakfast
# 23              Morning Burst® Facial Scrub Cleansers    personal care
# 24                                   Salmon Pinwheels     meat seafood
#
#                                  department_predicted
# 0               babies: diapers & accessories diapers
# 1                                        frozen goods
# 2                         alcoholic beverages spirits
# 3                                              bakery
# 4                           personal care soap & bath
# 5   household: pantry: cleaning: broom & mop: broo...
# 6                                 deli meats & cheese
# 7   beverages alcohol juice cranberry raspberry ju...
# 8                     dairy eggs butter & cheese eggs
# 9                                        canned goods
# 10                            dairy eggs & dairy eggs
# 11                           snacks chocolate & candy
# 12      dry goods pasta, rice, beans and grains pasta
# 13  personal care toiletries personal care toiletr...
# 14                                          beverages
# 15  international foods dry goods spices & seasoni...
# 16                                  breakfast cereals
# 17                   dairy eggs & cheese frozen dairy
# 18                                meat seafood frozen
# 19  household essentials candles & accessories sce...
# 20                                        frozen food
# 21         dairy eggs dairy egg products soy products
# 22                                    breakfast foods
# 23                                      personal care
# 24                          meat seafood fish seafood
